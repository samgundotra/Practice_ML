# %%
from bs4 import BeautifulSoup as bs
import numpy as np
import pandas as pd
import requests

# %%
data = pd.read_csv('chord_data.csv')
print(data)
# Out:
#         1      0     4   1.1    0.1   4.1    1.2   0.2    4.2   1.3   0.3  \
# 0     612     48   612    48    612    48    612    48    612    48   612
# 1     612     48   612    48    612    48    612    48    612    48     0
# 2      68      4     1     5     68     4      1     5     68     4     1
# 3      68      4     1     5     68     4      1     5     68     4     1
# 4       1      5     5     1      1     4      4     1      5     1    68
# 5      68     68     4     4      1     5     68     4      1     5    68
# 6       5     68     4     1      5    68      4     1      5    68     4
# 7      39     39     9     6     39     9     39     9     39    39     6
# 8    3107     18   487   413   3107    18    487   413   3107    18   487
# 9    3107     18   487   413   3107    18    487   413   3107   287     6
# 10      0      3     0     0      0    58      1     3     38     3     3
# 11     18      3    58     4     18     3     58     4     18     3    58
# ...

# %%
"""
C = 0
D = 1
E = 2
F = 3
G = 4
A = 5
B = 6
m = 8
# = 9
maj = 10
sus = 11
b = 12
dim = 13
aug = 14
"""
# Out:
# '\nC = 0\nD = 1\nE = 2\nF = 3\nG = 4\nA = 5\nB = 6\nm = 8\n# = 9\nmaj = 10\nsus = 11\nb = 12\ndim = 13\n'

# %%
notes = []
